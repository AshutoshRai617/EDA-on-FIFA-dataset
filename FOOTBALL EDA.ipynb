# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("FIFA_Processed_Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      ID               Name  Age  \
# 0           0             0  158023           L. Messi   31
# 1           1             1   20801  Cristiano Ronaldo   33
# 2           2             2  190871          Neymar Jr   26
# 3           3             3  193080             De Gea   27
# 4           4             4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  ... Composure  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  ...      96.0
# 1  https://cdn.sofifa.org/flags/38.png       94         94  ...      95.0
# 2  https://cdn.sofifa.org/flags/54.png       92         93  ...      94.0
# 3  https://cdn.sofifa.org/flags/45.png       91         93  ...      68.0
# 4   https://cdn.sofifa.org/flags/7.png       91         92  ...      88.0
#
#   Marking  StandingTackle  SlidingTackle  GKDiving GKHandling  GKKicking  \
# 0    33.0            28.0           26.0       6.0       11.0       15.0
# 1    28.0            31.0           23.0       7.0       11.0       15.0
# 2    27.0            24.0           33.0       9.0        9.0       15.0
# 3    15.0            21.0           13.0      90.0       85.0       87.0
# 4    68.0            58.0           51.0      15.0       13.0        5.0
#
#    GKPositioning  GKReflexes Release Clause
# 0           14.0         8.0        €226.5M
# 1           14.0        11.0        €127.1M
# 2           15.0        11.0        €228.1M
# 3           88.0        94.0        €138.6M
# 4           10.0        13.0        €196.4M
#
# [5 rows x 90 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1             ID           Age       Overall  \
# count  18207.000000  18207.000000   18207.000000  18207.000000  18207.000000
# mean    9103.000000   9103.000000  214298.338606     25.122206     66.238699
# std     5256.052511   5256.052511   29965.244204      4.669943      6.908930
# min        0.000000      0.000000      16.000000     16.000000     46.000000
# 25%     4551.500000   4551.500000  200315.500000     21.000000     62.000000
# 50%     9103.000000   9103.000000  221759.000000     25.000000     66.000000
# 75%    13654.500000  13654.500000  236529.500000     28.000000     71.000000
# max    18206.000000  18206.000000  246620.000000     45.000000     94.000000
#
#           Potential          Value           Wage       Special  \
# count  18207.000000   18207.000000   18207.000000  18207.000000
# mean      71.307299    9731.312133    9731.312133   1597.809908
# std        6.136496   21999.290406   21999.290406    272.586016
# min       48.000000       0.000000       0.000000    731.000000
# 25%       67.000000    1000.000000    1000.000000   1457.000000
# 50%       71.000000    3000.000000    3000.000000   1635.000000
# 75%       75.000000    9000.000000    9000.000000   1787.000000
# max       95.000000  565000.000000  565000.000000   2346.000000
#
#        International Reputation  ...     Penalties     Composure  \
# count              18207.000000  ...  18207.000000  18207.000000
# mean                   1.110287  ...     48.420607     58.493656
# std                    0.397630  ...     15.879699     11.810375
# min                    0.000000  ...      0.000000      0.000000
# 25%                    1.000000  ...     39.000000     51.000000
# 50%                    1.000000  ...     49.000000     59.000000
# 75%                    1.000000  ...     60.000000     67.000000
# max                    5.000000  ...     92.000000     96.000000
#
#             Marking  StandingTackle  SlidingTackle      GKDiving  \
# count  18207.000000    18207.000000   18207.000000  18207.000000
# mean      47.156973       47.572088      45.541056     16.572417
# std       20.025458       21.773243      21.389596     17.692536
# min        0.000000        0.000000       0.000000      0.000000
# 25%       30.000000       26.000000      24.000000      8.000000
# 50%       53.000000       55.000000      52.000000     11.000000
# 75%       64.000000       66.000000      64.000000     14.000000
# max       94.000000       93.000000      91.000000     90.000000
#
#          GKHandling     GKKicking  GKPositioning    GKReflexes
# count  18207.000000  18207.000000   18207.000000  18207.000000
# mean      16.348382     16.189268      16.345691     16.666831
# std       16.905507     16.502101      17.032944     17.951898
# min        0.000000      0.000000       0.000000      0.000000
# 25%        8.000000      8.000000       8.000000      8.000000
# 50%       11.000000     11.000000      11.000000     11.000000
# 75%       14.000000     14.000000      14.000000     14.000000
# max       92.000000     91.000000      90.000000     94.000000
#
# [8 rows x 75 columns]

# %%
df.describe(exclude='number')
# Out:
#                 Name                                           Photo  \
# count          18207                                           18207
# unique         17194                                           18207
# top     J. Rodríguez  https://cdn.sofifa.org/players/4/19/158023.png
# freq              11                                               1
#
#        Nationality                                 Flag   Club  \
# count        18207                                18207  18207
# unique         164                                  164    652
# top        England  https://cdn.sofifa.org/flags/14.png      0
# freq          1662                                 1662    241
#
#                                            Club Logo Preferred Foot  \
# count                                          18207          18159
# unique                                           679              2
# top     https://cdn.sofifa.org/teams/2/light/241.png          Right
# freq                                              33          13948
#
#              Work Rate Body Type Real Face Position Joined Loaned From  \
# count            18207     18207     18207    18147  18207       18207
# unique               9         3         2       27   1737         342
# top     Medium/ Medium    Normal        No       ST      0           0
# freq              9858     10647     16553     2152   1553       16943
#
#        Contract Valid Until Release Clause
# count                 18207          18207
# unique                   37           1245
# top                    2019              0
# freq                   4819           1564

# %%
df.shape
# Out:
# (18207, 90)

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'],inplace=True)

# %%
df.drop(columns=['Photo','Club Logo','Flag'],inplace=True)

# %%
df.shape
# Out:
# (18207, 85)

# %%
df.isna().sum()
# Out:
# ID                0
# Name              0
# Age               0
# Nationality       0
# Overall           0
#                  ..
# GKHandling        0
# GKKicking         0
# GKPositioning     0
# GKReflexes        0
# Release Clause    0
# Length: 85, dtype: int64

# %%
def fun_convert(df_value):
    
    if(pd.isna(df_value))!= True:
        try:
            value = float(df_value[1:-1])
            suffix = df_value[-1]

            if suffix == 'M':
                value = value * 1000000
            elif suffix == 'K':
                value = value * 1000
        except ValueError:
            value = 0
        return value
    else:
        return df_value

df['Release Clause']=df['Release Clause'].apply(fun_convert)

# %%
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club   Value    Wage  Special  ... Composure  Marking  \
# 0         FC Barcelona  565000  565000     2202  ...      96.0     33.0
# 1             Juventus  405000  405000     2228  ...      95.0     28.0
# 2  Paris Saint-Germain  290000  290000     2143  ...      94.0     27.0
# 3    Manchester United  260000  260000     1471  ...      68.0     15.0
# 4      Manchester City  355000  355000     2281  ...      88.0     68.0
#
#    StandingTackle  SlidingTackle GKDiving GKHandling GKKicking GKPositioning  \
# 0            28.0           26.0      6.0       11.0      15.0          14.0
# 1            31.0           23.0      7.0       11.0      15.0          14.0
# 2            24.0           33.0      9.0        9.0      15.0          15.0
# 3            21.0           13.0     90.0       85.0      87.0          88.0
# 4            58.0           51.0     15.0       13.0       5.0          10.0
#
#    GKReflexes Release Clause
# 0         8.0    226500000.0
# 1        11.0    127100000.0
# 2        11.0    228100000.0
# 3        94.0    138600000.0
# 4        13.0    196400000.0
#
# [5 rows x 85 columns]

# %%
players_by_country=df.groupby(['Nationality'])

# %%
players_by_clubs=df.groupby(['Club'])

# %%
data={'Name':df.Name,'Overall':df.Overall,'Potential':df.Potential,'Wage':df.Wage,'Release Clause':df['Release Clause']}
perf_df=pd.DataFrame(data,columns=['Name','Overall','Potential','Wage','Release Clause'])

# %%
fig = plt.gcf()
fig.set_size_inches(10, 8)
sns.displot(perf_df['Overall'],bins=10,color='r')

# %% [markdown]
# #### Most of the players lie in the overall range of 60-70.
#
# #### very few players have overall >90

# %%
perf_df.head()
# Out:
#                 Name  Overall  Potential    Wage  Release Clause
# 0           L. Messi       94         94  565000     226500000.0
# 1  Cristiano Ronaldo       94         94  405000     127100000.0
# 2          Neymar Jr       92         93  290000     228100000.0
# 3             De Gea       91         93  260000     138600000.0
# 4       K. De Bruyne       91         92  355000     196400000.0

# %% [markdown]
# ###### Players with Hightest overall

# %%
potential=pd.DataFrame(perf_df.sort_values(by=['Overall'],ascending=False))
potential.reset_index(drop=True, inplace=True)
potential.head(20)
# Out:
#                  Name  Overall  Potential    Wage  Release Clause
# 0            L. Messi       94         94  565000     226500000.0
# 1   Cristiano Ronaldo       94         94  405000     127100000.0
# 2           Neymar Jr       92         93  290000     228100000.0
# 3              De Gea       91         93  260000     138600000.0
# 4        K. De Bruyne       91         92  355000     196400000.0
# 5           E. Hazard       91         91  340000     172100000.0
# 6           L. Modrić       91         91  420000     137400000.0
# 7           L. Suárez       91         91  455000     164000000.0
# 8        Sergio Ramos       91         91  380000     104600000.0
# 9            D. Godín       90         90  125000      90200000.0
# 10        David Silva       90         90  285000     111000000.0
# 11           J. Oblak       90         93   94000     144500000.0
# 12           T. Kroos       90         90  355000     156800000.0
# 13     R. Lewandowski       90         90  205000     127100000.0
# 14    Sergio Busquets       89         89  315000     105600000.0
# 15       G. Chiellini       89         89  215000      44600000.0
# 16          S. Agüero       89         89  300000     119300000.0
# 17           M. Neuer       89         89  130000      62700000.0
# 18          E. Cavani       89         89  200000     111000000.0
# 19            H. Kane       89         91  205000     160700000.0

# %% [markdown]
# ###### Players with Heighest Potentials

# %%
potential=pd.DataFrame(perf_df.sort_values(by=['Potential'],ascending=False))
potential.reset_index(drop=True, inplace=True)
potential.head(20)
# Out:
#                  Name  Overall  Potential    Wage  Release Clause
# 0           K. Mbappé       88         95  100000     166100000.0
# 1            L. Messi       94         94  565000     226500000.0
# 2           P. Dybala       89         94  205000     153500000.0
# 3   Cristiano Ronaldo       94         94  405000     127100000.0
# 4           Neymar Jr       92         93  290000     228100000.0
# 5              De Gea       91         93  260000     138600000.0
# 6            J. Oblak       90         93   94000     144500000.0
# 7       G. Donnarumma       82         93   23000      55100000.0
# 8     Vinícius Júnior       77         92   66000      46800000.0
# 9          O. Dembélé       83         92  155000      90000000.0
# 10      Gabriel Jesus       83         92  130000      84100000.0
# 11      Marco Asensio       85         92  215000     121500000.0
# 12        M. Škriniar       85         92   82000      88400000.0
# 13          S. Umtiti       87         92  205000     121100000.0
# 14      M. ter Stegen       89         92  240000     123300000.0
# 15            L. Sané       86         92  195000     125100000.0
# 16       K. De Bruyne       91         92  355000     196400000.0
# 17            H. Kane       89         91  205000     160700000.0
# 18          L. Suárez       91         91  455000     164000000.0
# 19           P. Pogba       87         91  210000     123200000.0

# %% [markdown]
# ##### Players with heighest wage

# %%
potential=pd.DataFrame(perf_df.sort_values(by=['Wage'],ascending=False))
potential.reset_index(drop=True, inplace=True)
potential.head(20)
# Out:
#                  Name  Overall  Potential    Wage  Release Clause
# 0            L. Messi       94         94  565000     226500000.0
# 1           L. Suárez       91         91  455000     164000000.0
# 2           L. Modrić       91         91  420000     137400000.0
# 3   Cristiano Ronaldo       94         94  405000     127100000.0
# 4        Sergio Ramos       91         91  380000     104600000.0
# 5            T. Kroos       90         90  355000     156800000.0
# 6             G. Bale       88         88  355000     123000000.0
# 7        K. De Bruyne       91         92  355000     196400000.0
# 8           E. Hazard       91         91  340000     172100000.0
# 9            Coutinho       88         89  340000     147700000.0
# 10               Isco       88         91  315000     156200000.0
# 11       J. Rodríguez       88         89  315000             0.0
# 12    Sergio Busquets       89         89  315000     105600000.0
# 13          S. Agüero       89         89  300000     119300000.0
# 14          Neymar Jr       92         93  290000     228100000.0
# 15        David Silva       90         90  285000     111000000.0
# 16           Casemiro       88         90  285000     126400000.0
# 17            Marcelo       88         88  285000      88200000.0
# 18      P. Aubameyang       88         88  265000     112100000.0
# 19         I. Rakitić       87         87  260000      95300000.0

# %%
perf_df.corr()
# Out:
#                  Overall  Potential      Wage  Release Clause
# Overall         1.000000   0.660939  0.571926        0.589200
# Potential       0.660939   1.000000  0.486413        0.547668
# Wage            0.571926   0.486413  1.000000        0.820162
# Release Clause  0.589200   0.547668  0.820162        1.000000

# %%
fig = plt.gcf()
fig.set_size_inches(10, 8)
sns.heatmap(perf_df.corr())
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

fig = plt.gcf()

fig.set_size_inches(12, 8)

sns.scatterplot(x=perf_df.Wage,y=perf_df.Overall,hue=perf_df.Overall)
# Out:
# <AxesSubplot:xlabel='Wage', ylabel='Overall'>

# %% [markdown]
# Important points:-
#
# 1.There is a strong Co-relation between wage and Overall
#
# 2.There is a strong Co-relation between wage and Overall

# %%
perf_df.sort_values(by=['Release Clause'],ascending=False).head(20).reset_index()
# Out:
#     index               Name  Overall  Potential    Wage  Release Clause
# 0       2          Neymar Jr       92         93  290000     228100000.0
# 1       0           L. Messi       94         94  565000     226500000.0
# 2       4       K. De Bruyne       91         92  355000     196400000.0
# 3       5          E. Hazard       91         91  340000     172100000.0
# 4      25          K. Mbappé       88         95  100000     166100000.0
# 5      17       A. Griezmann       89         90  145000     165800000.0
# 6       7          L. Suárez       91         91  455000     164000000.0
# 7      16            H. Kane       89         91  205000     160700000.0
# 8      11           T. Kroos       90         90  355000     156800000.0
# 9      30               Isco       88         91  315000     156200000.0
# 10     15          P. Dybala       89         94  205000     153500000.0
# 11     32           Coutinho       88         89  340000     147700000.0
# 12      9           J. Oblak       90         93   94000     144500000.0
# 13     31         C. Eriksen       88         91  205000     141500000.0
# 14      3             De Gea       91         93  260000     138600000.0
# 15      6          L. Modrić       91         91  420000     137400000.0
# 16     26           M. Salah       88         89  255000     137300000.0
# 17     10     R. Lewandowski       90         90  205000     127100000.0
# 18      1  Cristiano Ronaldo       94         94  405000     127100000.0
# 19     27           Casemiro       88         90  285000     126400000.0

# %%
physical_traits_data={'Name':df.Name,'Age':df.Age,'Height':df.Height,'Weight':df.Weight,'Overall':df.Overall,'Potential':df.Potential}
physical_df=pd.DataFrame(physical_traits_data,columns=['Name','Age','Height','Weight','Overall','Potential'])
physical_df
# Out:
#                      Name  Age  Height  Weight  Overall  Potential
# 0                L. Messi   31      67     159       94         94
# 1       Cristiano Ronaldo   33      74     183       94         94
# 2               Neymar Jr   26      69     150       92         93
# 3                  De Gea   27      76     168       91         93
# 4            K. De Bruyne   27      71     154       91         92
# ...                   ...  ...     ...     ...      ...        ...
# 18202        J. Lundstram   19      69     134       47         65
# 18203  N. Christoffersson   19      75     170       47         63
# 18204           B. Worman   16      68     148       47         67
# 18205      D. Walker-Rice   17      70     154       47         66
# 18206           G. Nugent   16      70     176       46         66
#
# [18207 rows x 6 columns]

# %%
physical_df.corr()
# Out:
#                 Age    Height    Weight   Overall  Potential
# Age        1.000000  0.049437  0.202416  0.452350  -0.253312
# Height     0.049437  1.000000  0.776673  0.048137   0.024638
# Weight     0.202416  0.776673  1.000000  0.150751   0.011892
# Overall    0.452350  0.048137  0.150751  1.000000   0.660939
# Potential -0.253312  0.024638  0.011892  0.660939   1.000000

# %%
fig = plt.gcf()
fig.set_size_inches(10, 8)
sns.heatmap(physical_df.corr())
# Out:
# <AxesSubplot:>

# %%
wagebill=players_by_clubs['Wage'].sum().sort_values(ascending=False).nlargest(10)
wagebill
# Out:
# Club
# Real Madrid          5017000
# FC Barcelona         4837000
# Manchester City      3741000
# Manchester United    3391000
# Juventus             3292000
# Chelsea              3249000
# Liverpool            2902000
# Tottenham Hotspur    2623000
# Arsenal              2588000
# FC Bayern München    2286000
# Name: Wage, dtype: int64

# %% [markdown]
# ### THESE ARE THE CLUBS WITH MOST WAGES

# %%
fig = plt.gcf()
fig.set_size_inches(10, 8)
sns.barplot(x=wagebill.index,y=wagebill)
# Out:
# <AxesSubplot:xlabel='Club', ylabel='Wage'>

# %% [markdown]
# THESE ARE THE TOP 15 CLUBS IN WORLD THAT HAVE MOST WAGES

# %%
richcountry=players_by_country['Wage'].sum().sort_values(ascending=False).nlargest(10)
richcountry
# Out:
# Nationality
# Spain          17498000
# England        16526000
# Brazil         14703000
# France         12845000
# Germany        11548000
# Argentina      10778000
# Italy           9462000
# Belgium         4805000
# Portugal        4608000
# Netherlands     4546000
# Name: Wage, dtype: int64

# %%
fig = plt.gcf()
fig.set_size_inches(14, 8)
sns.barplot(x=richcountry.index,y=richcountry)
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='Wage'>

# %% [markdown]
# ### COUNTRIES WITH RICH PLAYERS

# %%
players_by_positions=df.groupby(['Position'])

# %%
df.Position.unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
df.Position.value_counts()
# Out:
# ST     2152
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %%
fig = plt.gcf()
fig.set_size_inches(14, 8)
sns.barplot(x=df.Position.value_counts().index,y=df.Position.value_counts())
# Out:
# <AxesSubplot:ylabel='Position'>

# %%
position_group=df.groupby(['Position'])

# %%
fifa_sorted = df.groupby(['Position']).apply(lambda x:x.sort_values(by='Overall', ascending = False, axis = 0))
fifa_top100=df.groupby(['Position']).apply(lambda x:x.sort_values(by='Overall', ascending = False, axis = 0).head(100))
fifa_sorted
# Out:
#                     ID                Name  Age          Nationality  Overall  \
# Position
# CAM      17     194765        A. Griezmann   27               France       89
#          31     190460          C. Eriksen   26              Denmark       88
#          61     201942     Roberto Firmino   26               Brazil       86
#          66     189596           T. Müller   28              Germany       86
#          74     176635             M. Özil   29              Germany       86
# ...                ...                 ...  ...                  ...      ...
# ST       18177  238550           R. Roache   18  Republic of Ireland       48
#          18189  240160          A. Kaltner   18              Germany       47
#          18200  231381            J. Young   18             Scotland       47
#          18203  243165  N. Christoffersson   19               Sweden       47
#          18204  241638           B. Worman   16              England       47
#
#                 Potential                Club   Value    Wage  Special  ...  \
# Position                                                                ...
# CAM      17            90     Atlético Madrid  145000  145000     2246  ...
#          31            91   Tottenham Hotspur  205000  205000     2117  ...
#          61            87           Liverpool  195000  195000     2187  ...
#          66            86   FC Bayern München  135000  135000     2097  ...
#          74            86             Arsenal  190000  190000     1911  ...
# ...                   ...                 ...     ...     ...      ...  ...
# ST       18177         69           Blackpool    1000    1000     1178  ...
#          18189         61  SpVgg Unterhaching    1000    1000     1290  ...
#          18200         62        Swindon Town    1000    1000     1203  ...
#          18203         63      Trelleborgs FF    1000    1000     1098  ...
#          18204         67    Cambridge United    1000    1000     1189  ...
#
#                Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# CAM      17         87.0     59.0            47.0           48.0     14.0
#          31         88.0     59.0            57.0           22.0      9.0
#          61         87.0     60.0            64.0           42.0      8.0
#          66         83.0     44.0            41.0           44.0      6.0
#          74         82.0     24.0            16.0           19.0      6.0
# ...                  ...      ...             ...            ...      ...
# ST       18177      49.0     18.0            16.0           11.0      6.0
#          18189      37.0     28.0            15.0           22.0     15.0
#          18200      50.0     15.0            17.0           14.0     11.0
#          18203      42.0     22.0            15.0           19.0     10.0
#          18204      41.0     32.0            13.0           11.0      6.0
#
#                GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CAM      17           8.0      14.0          13.0        14.0    165800000.0
#          31          14.0       7.0           7.0         6.0    141500000.0
#          61          11.0       9.0           6.0        10.0    104700000.0
#          66           7.0      11.0          14.0        14.0     74300000.0
#          74          14.0      10.0           6.0        14.0     82700000.0
# ...                   ...       ...           ...         ...            ...
# ST       18177        9.0      11.0           7.0        12.0       193000.0
#          18189        5.0      14.0          12.0         8.0       125000.0
#          18200       15.0      12.0          12.0        11.0       143000.0
#          18203        9.0       9.0           5.0        12.0       113000.0
#          18204        5.0      10.0           6.0        13.0       165000.0
#
# [18147 rows x 85 columns]

# %% [markdown]
# ## ST

# %%
fifa_st = fifa_sorted[fifa_sorted['Position']=='ST']
fifa_st.head(10)
# Out:
#                   ID               Name  Age Nationality  Overall  Potential  \
# Position
# ST       1     20801  Cristiano Ronaldo   33    Portugal       94         94
#          10   188545     R. Lewandowski   29      Poland       90         90
#          16   202126            H. Kane   24     England       89         91
#          23   153079          S. Agüero   30   Argentina       89         89
#          36   173731            G. Bale   28       Wales       88         88
#          43   201399          M. Icardi   25   Argentina       87         90
#          47   192505          R. Lukaku   25     Belgium       87         89
#          48   192387        C. Immobile   28       Italy       87         87
#          105  165153         K. Benzema   30      France       85         85
#          87   193301       A. Lacazette   27      France       85         86
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# ST       1             Juventus  405000  405000     2228  ...      95.0
#          10   FC Bayern München  205000  205000     2152  ...      86.0
#          16   Tottenham Hotspur  205000  205000     2165  ...      89.0
#          23     Manchester City  300000  300000     2107  ...      90.0
#          36         Real Madrid  355000  355000     2279  ...      86.0
#          43               Inter  130000  130000     1940  ...      85.0
#          47   Manchester United  230000  230000     2031  ...      83.0
#          48               Lazio  115000  115000     2009  ...      81.0
#          105        Real Madrid  240000  240000     2000  ...      79.0
#          87             Arsenal  180000  180000     2060  ...      85.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# ST       1       28.0            31.0           23.0      7.0       11.0
#          10      34.0            42.0           19.0     15.0        6.0
#          16      56.0            36.0           38.0      8.0       10.0
#          23      30.0            20.0           12.0     13.0       15.0
#          36      54.0            55.0           52.0     15.0       15.0
#          43      45.0            24.0           20.0     13.0        9.0
#          47      30.0            30.0           30.0      8.0       15.0
#          48      34.0            33.0           32.0      6.0        8.0
#          105     47.0            15.0           12.0     13.0       11.0
#          87      29.0            42.0           30.0     11.0        6.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# ST       1        15.0          14.0        11.0    127100000.0
#          10       12.0           8.0        10.0    127100000.0
#          16       11.0          14.0        11.0    160700000.0
#          23        6.0          11.0        14.0    119300000.0
#          36       11.0           5.0         6.0    123000000.0
#          43        5.0           7.0         9.0    114500000.0
#          47       14.0           7.0        10.0    120300000.0
#          48       15.0          12.0         6.0     88400000.0
#          105       5.0           5.0         7.0     75900000.0
#          87        9.0           5.0         6.0     88900000.0
#
# [10 rows x 85 columns]

# %%
fifa_st.shape
# Out:
# (2152, 85)

# %%
fifa_st.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID               Name  Age         Nationality  Overall  \
# Position
# ST       1     20801  Cristiano Ronaldo   33            Portugal       94
#          36   173731            G. Bale   28               Wales       88
#          23   153079          S. Agüero   30           Argentina       89
#          105  165153         K. Benzema   30              France       85
#          47   192505          R. Lukaku   25             Belgium       87
#          16   202126            H. Kane   24             England       89
#          10   188545     R. Lewandowski   29              Poland       90
#          87   193301       A. Lacazette   27              France       85
#          139  181783       M. Mandžukić   32             Croatia       84
#          430  221639            Mariano   24  Dominican Republic       80
#
#               Potential               Club   Value    Wage  Special  ...  \
# Position                                                             ...
# ST       1           94           Juventus  405000  405000     2228  ...
#          36          88        Real Madrid  355000  355000     2279  ...
#          23          89    Manchester City  300000  300000     2107  ...
#          105         85        Real Madrid  240000  240000     2000  ...
#          47          89  Manchester United  230000  230000     2031  ...
#          16          91  Tottenham Hotspur  205000  205000     2165  ...
#          10          90  FC Bayern München  205000  205000     2152  ...
#          87          86            Arsenal  180000  180000     2060  ...
#          139         84           Juventus  160000  160000     2106  ...
#          430         85        Real Madrid  140000  140000     2041  ...
#
#              Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# ST       1        95.0     28.0            31.0           23.0      7.0
#          36       86.0     54.0            55.0           52.0     15.0
#          23       90.0     30.0            20.0           12.0     13.0
#          105      79.0     47.0            15.0           12.0     13.0
#          47       83.0     30.0            30.0           30.0      8.0
#          16       89.0     56.0            36.0           38.0      8.0
#          10       86.0     34.0            42.0           19.0     15.0
#          87       85.0     29.0            42.0           30.0     11.0
#          139      80.0     59.0            64.0           64.0     10.0
#          430      68.0     41.0            40.0           34.0     12.0
#
#              GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# ST       1         11.0      15.0          14.0        11.0    127100000.0
#          36        15.0      11.0           5.0         6.0    123000000.0
#          23        15.0       6.0          11.0        14.0    119300000.0
#          105       11.0       5.0           5.0         7.0     75900000.0
#          47        15.0      14.0           7.0        10.0    120300000.0
#          16        10.0      11.0          14.0        11.0    160700000.0
#          10         6.0      12.0           8.0        10.0    127100000.0
#          87         6.0       9.0           5.0         6.0     88900000.0
#          139        8.0       5.0           8.0        15.0     41300000.0
#          430       14.0       6.0           8.0        15.0     42500000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_st['Overall'],bins=10,color='r')

# %%
fifa_topst=fifa_top100[fifa_top100['Position']=='ST']
fifa_topst.Club.value_counts().head(10)
# Out:
# Real Madrid               3
# Valencia CF               3
# SL Benfica                3
# Juventus                  2
# Borussia Dortmund         2
# SV Werder Bremen          2
# Olympique de Marseille    2
# Real Betis                2
# Bayer 04 Leverkusen       2
# Liverpool                 2
# Name: Club, dtype: int64

# %%
fifa_topst.Nationality.value_counts().head(10)
# Out:
# Spain          14
# Argentina      12
# Brazil          9
# France          8
# England         6
# Germany         5
# Italy           4
# Turkey          3
# Belgium         3
# Netherlands     3
# Name: Nationality, dtype: int64

# %% [markdown]
# ## CAM

# %%
fifa_cam = fifa_sorted[fifa_sorted['Position']=='CAM']
fifa_cam.head(10)
# Out:
#                   ID              Name  Age Nationality  Overall  Potential  \
# Position
# CAM      17   194765      A. Griezmann   27      France       89         90
#          31   190460        C. Eriksen   26     Denmark       88         91
#          61   201942   Roberto Firmino   26      Brazil       86         87
#          66   189596         T. Müller   28     Germany       86         86
#          74   176635           M. Özil   29     Germany       86         86
#          80   216594          N. Fekir   24      France       85         89
#          96   181872          A. Vidal   31       Chile       85         85
#          101  178518     R. Nainggolan   30     Belgium       85         85
#          144  177388          D. Payet   31      France       84         84
#          166  212523  Anderson Talisca   24      Brazil       83         90
#
#                                         Club   Value    Wage  Special  ...  \
# Position                                                               ...
# CAM      17                  Atlético Madrid  145000  145000     2246  ...
#          31                Tottenham Hotspur  205000  205000     2117  ...
#          61                        Liverpool  195000  195000     2187  ...
#          66                FC Bayern München  135000  135000     2097  ...
#          74                          Arsenal  190000  190000     1911  ...
#          80               Olympique Lyonnais   92000   92000     2102  ...
#          96                     FC Barcelona  205000  205000     2230  ...
#          101                           Inter  105000  105000     2278  ...
#          144          Olympique de Marseille   75000   75000     2053  ...
#          166  Guangzhou Evergrande Taobao FC   18000   18000     2142  ...
#
#              Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# CAM      17       87.0     59.0            47.0           48.0     14.0
#          31       88.0     59.0            57.0           22.0      9.0
#          61       87.0     60.0            64.0           42.0      8.0
#          66       83.0     44.0            41.0           44.0      6.0
#          74       82.0     24.0            16.0           19.0      6.0
#          80       89.0     31.0            37.0           25.0     15.0
#          96       81.0     82.0            87.0           86.0      4.0
#          101      84.0     83.0            86.0           90.0     11.0
#          144      82.0     32.0            36.0           39.0     11.0
#          166      74.0     55.0            62.0           42.0     13.0
#
#              GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CAM      17         8.0      14.0          13.0        14.0    165800000.0
#          31        14.0       7.0           7.0         6.0    141500000.0
#          61        11.0       9.0           6.0        10.0    104700000.0
#          66         7.0      11.0          14.0        14.0     74300000.0
#          74        14.0      10.0           6.0        14.0     82700000.0
#          80         9.0       8.0          14.0        15.0     98800000.0
#          96         2.0       4.0           2.0         4.0     53300000.0
#          101       11.0      14.0           8.0        11.0     60400000.0
#          144       15.0       9.0          14.0        12.0     52300000.0
#          166       11.0      13.0          12.0        10.0            0.0
#
# [10 rows x 85 columns]

# %%
fifa_cam.shape
# Out:
# (958, 85)

# %%
fifa_st.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID               Name  Age         Nationality  Overall  \
# Position
# ST       1     20801  Cristiano Ronaldo   33            Portugal       94
#          36   173731            G. Bale   28               Wales       88
#          23   153079          S. Agüero   30           Argentina       89
#          105  165153         K. Benzema   30              France       85
#          47   192505          R. Lukaku   25             Belgium       87
#          16   202126            H. Kane   24             England       89
#          10   188545     R. Lewandowski   29              Poland       90
#          87   193301       A. Lacazette   27              France       85
#          139  181783       M. Mandžukić   32             Croatia       84
#          430  221639            Mariano   24  Dominican Republic       80
#
#               Potential               Club   Value    Wage  Special  ...  \
# Position                                                             ...
# ST       1           94           Juventus  405000  405000     2228  ...
#          36          88        Real Madrid  355000  355000     2279  ...
#          23          89    Manchester City  300000  300000     2107  ...
#          105         85        Real Madrid  240000  240000     2000  ...
#          47          89  Manchester United  230000  230000     2031  ...
#          16          91  Tottenham Hotspur  205000  205000     2165  ...
#          10          90  FC Bayern München  205000  205000     2152  ...
#          87          86            Arsenal  180000  180000     2060  ...
#          139         84           Juventus  160000  160000     2106  ...
#          430         85        Real Madrid  140000  140000     2041  ...
#
#              Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# ST       1        95.0     28.0            31.0           23.0      7.0
#          36       86.0     54.0            55.0           52.0     15.0
#          23       90.0     30.0            20.0           12.0     13.0
#          105      79.0     47.0            15.0           12.0     13.0
#          47       83.0     30.0            30.0           30.0      8.0
#          16       89.0     56.0            36.0           38.0      8.0
#          10       86.0     34.0            42.0           19.0     15.0
#          87       85.0     29.0            42.0           30.0     11.0
#          139      80.0     59.0            64.0           64.0     10.0
#          430      68.0     41.0            40.0           34.0     12.0
#
#              GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# ST       1         11.0      15.0          14.0        11.0    127100000.0
#          36        15.0      11.0           5.0         6.0    123000000.0
#          23        15.0       6.0          11.0        14.0    119300000.0
#          105       11.0       5.0           5.0         7.0     75900000.0
#          47        15.0      14.0           7.0        10.0    120300000.0
#          16        10.0      11.0          14.0        11.0    160700000.0
#          10         6.0      12.0           8.0        10.0    127100000.0
#          87         6.0       9.0           5.0         6.0     88900000.0
#          139        8.0       5.0           8.0        15.0     41300000.0
#          430       14.0       6.0           8.0        15.0     42500000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_cam['Overall'],bins=10,color='r')

# %%
fifa_topcam=fifa_top100[fifa_top100['Position']=='CAM']
fifa_topcam.Club.value_counts().head(10)
# Out:
# Liverpool                  3
# Eintracht Frankfurt        3
# Inter                      3
# Roma                       2
# Lokomotiv Moscow           2
# Galatasaray SK             2
# Athletic Club de Bilbao    2
# Al Hilal                   2
# FC Augsburg                2
# FC Barcelona               2
# Name: Club, dtype: int64

# %%
fifa_topcam.Nationality.value_counts().head(10)
# Out:
# Argentina    12
# Brazil       10
# Spain         8
# Germany       7
# France        6
# Colombia      4
# Croatia       4
# England       4
# Portugal      4
# Turkey        3
# Name: Nationality, dtype: int64

# %% [markdown]
# ## LW

# %%
fifa_lw = fifa_sorted[fifa_sorted['Position']=='LW']
fifa_lw.head(10)
# Out:
#                   ID         Name  Age Nationality  Overall  Potential  \
# Position
# LW       2    190871    Neymar Jr   26      Brazil       92         93
#          30   197781         Isco   26       Spain       88         91
#          32   189242     Coutinho   26      Brazil       88         89
#          29   198219   L. Insigne   27       Italy       88         88
#          55   222492      L. Sané   22     Germany       86         92
#          116  211300   A. Martial   22      France       84         90
#          319  231677  M. Rashford   20     England       81         89
#          334  216201     Williams   24       Spain       81         87
#          347  206467      A. Plea   25      France       81         83
#          384  183900   D. Perotti   29   Argentina       81         81
#
#                                   Club   Value    Wage  Special  ...  \
# Position                                                         ...
# LW       2         Paris Saint-Germain  290000  290000     2143  ...
#          30                Real Madrid  315000  315000     2137  ...
#          32               FC Barcelona  340000  340000     2175  ...
#          29                     Napoli  165000  165000     2017  ...
#          55            Manchester City  195000  195000     2090  ...
#          116         Manchester United  165000  165000     2064  ...
#          319         Manchester United  110000  110000     2062  ...
#          334   Athletic Club de Bilbao   31000   31000     2000  ...
#          347  Borussia Mönchengladbach   40000   40000     2054  ...
#          384                      Roma   84000   84000     1959  ...
#
#              Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# LW       2        94.0     27.0            24.0           33.0      9.0
#          30       86.0     60.0            64.0           51.0     10.0
#          32       85.0     55.0            54.0           47.0     12.0
#          29       83.0     51.0            24.0           22.0      8.0
#          55       78.0     36.0            32.0           35.0      8.0
#          116      79.0     38.0            39.0           36.0      9.0
#          319      73.0     32.0            40.0           33.0     11.0
#          334      71.0     52.0            38.0           31.0     14.0
#          347      76.0     29.0            40.0           30.0     11.0
#          384      81.0     58.0            31.0           22.0      5.0
#
#              GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# LW       2          9.0      15.0          15.0        11.0    228100000.0
#          30         8.0      12.0          15.0         6.0    156200000.0
#          32         7.0       9.0          14.0         6.0    147700000.0
#          29         4.0      14.0           9.0        10.0    105400000.0
#          55        12.0       9.0           9.0        14.0    125100000.0
#          116        8.0       8.0          15.0        11.0     87100000.0
#          319        6.0      15.0           7.0        14.0     55400000.0
#          334       15.0      14.0          10.0        13.0     56400000.0
#          347       15.0      16.0          12.0        15.0     39100000.0
#          384        8.0      14.0           6.0         8.0     29800000.0
#
# [10 rows x 85 columns]

# %%
fifa_lw.shape
# Out:
# (381, 85)

# %%
fifa_lw.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                    ID         Name  Age Nationality  Overall  Potential  \
# Position
# LW       32    189242     Coutinho   26      Brazil       88         89
#          30    197781         Isco   26       Spain       88         91
#          2     190871    Neymar Jr   26      Brazil       92         93
#          55    222492      L. Sané   22     Germany       86         92
#          29    198219   L. Insigne   27       Italy       88         88
#          116   211300   A. Martial   22      France       84         90
#          319   231677  M. Rashford   20     England       81         89
#          933   186146   D. Welbeck   27     England       77         77
#          384   183900   D. Perotti   29   Argentina       81         81
#          1342  186200    F. Borini   27       Italy       76         76
#
#                               Club   Value    Wage  Special  ... Composure  \
# Position                                                     ...
# LW       32           FC Barcelona  340000  340000     2175  ...      85.0
#          30            Real Madrid  315000  315000     2137  ...      86.0
#          2     Paris Saint-Germain  290000  290000     2143  ...      94.0
#          55        Manchester City  195000  195000     2090  ...      78.0
#          29                 Napoli  165000  165000     2017  ...      83.0
#          116     Manchester United  165000  165000     2064  ...      79.0
#          319     Manchester United  110000  110000     2062  ...      73.0
#          933               Arsenal   95000   95000     1965  ...      76.0
#          384                  Roma   84000   84000     1959  ...      81.0
#          1342                Milan   76000   76000     1958  ...      76.0
#
#                Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# LW       32       55.0            54.0           47.0     12.0        7.0
#          30       60.0            64.0           51.0     10.0        8.0
#          2        27.0            24.0           33.0      9.0        9.0
#          55       36.0            32.0           35.0      8.0       12.0
#          29       51.0            24.0           22.0      8.0        4.0
#          116      38.0            39.0           36.0      9.0        8.0
#          319      32.0            40.0           33.0     11.0        6.0
#          933      47.0            38.0           33.0      9.0       10.0
#          384      58.0            31.0           22.0      5.0        8.0
#          1342     68.0            30.0           26.0     11.0        6.0
#
#               GKKicking GKPositioning  GKReflexes Release Clause
# Position
# LW       32         9.0          14.0         6.0    147700000.0
#          30        12.0          15.0         6.0    156200000.0
#          2         15.0          15.0        11.0    228100000.0
#          55         9.0           9.0        14.0    125100000.0
#          29        14.0           9.0        10.0    105400000.0
#          116        8.0          15.0        11.0     87100000.0
#          319       15.0           7.0        14.0     55400000.0
#          933        6.0          12.0        16.0     18100000.0
#          384       14.0           6.0         8.0     29800000.0
#          1342       8.0          12.0         6.0     13600000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_lw['Overall'],bins=10,color='r')

# %%
fifa_toplw=fifa_top100[fifa_top100['Position']=='LW']
fifa_toplw.Club.value_counts().head(10)
# Out:
# Rio Ave FC                  3
# Fiorentina                  3
# SL Benfica                  3
# Real Madrid                 2
# 0                           2
# FC Girondins de Bordeaux    2
# Fulham                      2
# RC Celta                    2
# Wolverhampton Wanderers     2
# Benevento                   2
# Name: Club, dtype: int64

# %%
fifa_toplw=fifa_top100[fifa_top100['Position']=='CAM']
fifa_toplw.Nationality.value_counts().head(10)
# Out:
# Argentina    12
# Brazil       10
# Spain         8
# Germany       7
# France        6
# Colombia      4
# Croatia       4
# England       4
# Portugal      4
# Turkey        3
# Name: Nationality, dtype: int64

# %% [markdown]
# ## RW

# %%
fifa_rw = fifa_sorted[fifa_sorted['Position']=='RW']
fifa_rw.head(10)
# Out:
#                   ID             Name  Age Nationality  Overall  Potential  \
# Position
# RW       56   218667   Bernardo Silva   23    Portugal       86         91
#          60   202652      R. Sterling   23     England       86         89
#          79   220834    Marco Asensio   22       Spain       85         92
#          93   184941       A. Sánchez   29       Chile       85         85
#          84   204485        R. Mahrez   27     Algeria       85         85
#          140  180403          Willian   29      Brazil       84         84
#          167  212188        T. Werner   22     Germany       83         87
#          172  208618    Lucas Vázquez   27       Spain       83         83
#          183  202651             Suso   24       Spain       83         86
#          157  230481  Ronaldo Cabrais   26      Brazil       83         83
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# RW       56     Manchester City  180000  180000     2039  ...      85.0
#          60     Manchester City  195000  195000     2036  ...      77.0
#          79         Real Madrid  215000  215000     2050  ...      83.0
#          93   Manchester United  215000  215000     2172  ...      84.0
#          84     Manchester City  205000  205000     2031  ...      86.0
#          140            Chelsea  175000  175000     2052  ...      79.0
#          167         RB Leipzig   70000   70000     1967  ...      74.0
#          172        Real Madrid  205000  205000     2048  ...      75.0
#          183              Milan  115000  115000     1959  ...      76.0
#          157             Grêmio   51000   51000     2095  ...      81.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# RW       56      49.0            44.0           35.0      9.0       10.0
#          60      47.0            58.0           54.0     15.0       12.0
#          79      40.0            42.0           39.0     13.0        9.0
#          93      38.0            44.0           35.0     10.0       10.0
#          84      45.0            31.0           18.0     15.0        9.0
#          140     43.0            57.0           51.0     14.0       12.0
#          167     39.0            20.0           19.0      9.0        9.0
#          172     42.0            50.0           44.0      9.0       16.0
#          183     50.0            23.0           18.0     15.0       15.0
#          157     24.0            35.0           33.0     12.0       12.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# RW       56       14.0          12.0         9.0    114500000.0
#          60       12.0          15.0         9.0    108800000.0
#          79        6.0          12.0        10.0    121500000.0
#          93       15.0          12.0        13.0     69400000.0
#          84       13.0          11.0         6.0     74900000.0
#          140      13.0           7.0        13.0     56400000.0
#          167       8.0          15.0         9.0     61200000.0
#          172       9.0           9.0         7.0     55400000.0
#          183       9.0           8.0         9.0     58600000.0
#          157      13.0          15.0        13.0     50400000.0
#
# [10 rows x 85 columns]

# %%
fifa_rw.shape
# Out:
# (370, 85)

# %%
fifa_rw.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID            Name  Age Nationality  Overall  Potential  \
# Position
# RW       79   220834   Marco Asensio   22       Spain       85         92
#          93   184941      A. Sánchez   29       Chile       85         85
#          84   204485       R. Mahrez   27     Algeria       85         85
#          172  208618   Lucas Vázquez   27       Spain       83         83
#          60   202652     R. Sterling   23     England       86         89
#          56   218667  Bernardo Silva   23    Portugal       86         91
#          140  180403         Willian   29      Brazil       84         84
#          155  231443      O. Dembélé   21      France       83         92
#          283  189505           Pedro   30       Spain       82         82
#          236  222737          Malcom   21      Brazil       82         89
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# RW       79         Real Madrid  215000  215000     2050  ...      83.0
#          93   Manchester United  215000  215000     2172  ...      84.0
#          84     Manchester City  205000  205000     2031  ...      86.0
#          172        Real Madrid  205000  205000     2048  ...      75.0
#          60     Manchester City  195000  195000     2036  ...      77.0
#          56     Manchester City  180000  180000     2039  ...      85.0
#          140            Chelsea  175000  175000     2052  ...      79.0
#          155       FC Barcelona  155000  155000     1993  ...      75.0
#          283            Chelsea  140000  140000     1968  ...      77.0
#          236       FC Barcelona  140000  140000     1984  ...      78.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# RW       79      40.0            42.0           39.0     13.0        9.0
#          93      38.0            44.0           35.0     10.0       10.0
#          84      45.0            31.0           18.0     15.0        9.0
#          172     42.0            50.0           44.0      9.0       16.0
#          60      47.0            58.0           54.0     15.0       12.0
#          56      49.0            44.0           35.0      9.0       10.0
#          140     43.0            57.0           51.0     14.0       12.0
#          155     42.0            30.0           33.0      6.0        6.0
#          283     49.0            32.0           31.0      5.0       11.0
#          236     21.0            28.0           17.0      8.0       14.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# RW       79        6.0          12.0        10.0    121500000.0
#          93       15.0          12.0        13.0     69400000.0
#          84       13.0          11.0         6.0     74900000.0
#          172       9.0           9.0         7.0     55400000.0
#          60       12.0          15.0         9.0    108800000.0
#          56       14.0          12.0         9.0    114500000.0
#          140      13.0           7.0        13.0     56400000.0
#          155      14.0          10.0        13.0     90000000.0
#          283      12.0          15.0         9.0     38900000.0
#          236      15.0           7.0         9.0     70900000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_lw['Overall'],bins=10,color='r')

# %%
fifa_toprw=fifa_top100[fifa_top100['Position']=='RW']
fifa_toprw.Club.value_counts().head(10)
# Out:
# 0                          5
# Chelsea                    4
# Manchester City            3
# Parma                      3
# Vitesse                    3
# SL Benfica                 2
# Wolverhampton Wanderers    2
# Derby County               2
# Sporting Kansas City       2
# Monterrey                  2
# Name: Club, dtype: int64

# %% [markdown]
# ## CDM

# %%
fifa_rw = fifa_sorted[fifa_sorted['Position']=='CDM']
fifa_rw.head(10)
# Out:
#                   ID              Name  Age         Nationality  Overall  \
# Position
# CDM      20   189511   Sergio Busquets   29               Spain       89
#          27   200145          Casemiro   26              Brazil       88
#          72   180206         M. Pjanić   28  Bosnia Herzegovina       86
#          75   135507       Fernandinho   33              Brazil       86
#          118  209499           Fabinho   24              Brazil       84
#          120  207566  William Carvalho   26            Portugal       84
#          132  191202          N. Matić   29              Serbia       84
#          142  178562         E. Banega   30           Argentina       84
#          187  200888    Danilo Pereira   26            Portugal       83
#          203  189712      K. Strootman   28         Netherlands       83
#
#               Potential                    Club   Value    Wage  Special  ...  \
# Position                                                                  ...
# CDM      20          89            FC Barcelona  315000  315000     2065  ...
#          27          90             Real Madrid  285000  285000     2170  ...
#          72          86                Juventus  180000  180000     2182  ...
#          75          86         Manchester City  185000  185000     2183  ...
#          118         88               Liverpool  120000  120000     2164  ...
#          120         86              Real Betis   38000   38000     1985  ...
#          132         84       Manchester United  165000  165000     2100  ...
#          142         84              Sevilla FC   31000   31000     2133  ...
#          187         86                FC Porto   21000   21000     2028  ...
#          203         83  Olympique de Marseille   66000   66000     2139  ...
#
#              Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# CDM      20       90.0     90.0            86.0           80.0      5.0
#          27       84.0     88.0            90.0           87.0     13.0
#          72       86.0     75.0            74.0           70.0      7.0
#          75       79.0     85.0            85.0           80.0     12.0
#          118      84.0     83.0            86.0           84.0     13.0
#          120      89.0     84.0            85.0           68.0      6.0
#          132      84.0     83.0            84.0           75.0      7.0
#          142      80.0     75.0            69.0           64.0     13.0
#          187      84.0     83.0            84.0           75.0      9.0
#          203      85.0     75.0            84.0           75.0      7.0
#
#              GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CDM      20         8.0      13.0           9.0        13.0    105600000.0
#          27        14.0      16.0          12.0        12.0    126400000.0
#          72         7.0      13.0           7.0         8.0     72600000.0
#          75        11.0       5.0          13.0         7.0     33300000.0
#          118       12.0       6.0           8.0         8.0     67200000.0
#          120        6.0       5.0          14.0        14.0     68500000.0
#          132       15.0      12.0          14.0         9.0     44400000.0
#          142        8.0       7.0           7.0        10.0     60900000.0
#          187        7.0      13.0          14.0        15.0     56000000.0
#          203       12.0      11.0           6.0         7.0     39900000.0
#
# [10 rows x 85 columns]

# %%
fifa_rw.shape
# Out:
# (948, 85)

# %%
fifa_rw.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID             Name  Age         Nationality  Overall  \
# Position
# CDM      20   189511  Sergio Busquets   29               Spain       89
#          27   200145         Casemiro   26              Brazil       88
#          75   135507      Fernandinho   33              Brazil       86
#          72   180206        M. Pjanić   28  Bosnia Herzegovina       86
#          132  191202         N. Matić   29              Serbia       84
#          118  209499          Fabinho   24              Brazil       84
#          573  226161  Marcos Llorente   23               Spain       79
#          313  158963        L. Biglia   32           Argentina       82
#          215  177610    Javi Martínez   29               Spain       83
#          699  177358  M. Schneiderlin   28              France       79
#
#               Potential               Club   Value    Wage  Special  ...  \
# Position                                                             ...
# CDM      20          89       FC Barcelona  315000  315000     2065  ...
#          27          90        Real Madrid  285000  285000     2170  ...
#          75          86    Manchester City  185000  185000     2183  ...
#          72          86           Juventus  180000  180000     2182  ...
#          132         84  Manchester United  165000  165000     2100  ...
#          118         88          Liverpool  120000  120000     2164  ...
#          573         87        Real Madrid  110000  110000     1869  ...
#          313         82              Milan   98000   98000     2104  ...
#          215         83  FC Bayern München   94000   94000     1948  ...
#          699         79            Everton   92000   92000     1991  ...
#
#              Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# CDM      20       90.0     90.0            86.0           80.0      5.0
#          27       84.0     88.0            90.0           87.0     13.0
#          75       79.0     85.0            85.0           80.0     12.0
#          72       86.0     75.0            74.0           70.0      7.0
#          132      84.0     83.0            84.0           75.0      7.0
#          118      84.0     83.0            86.0           84.0     13.0
#          573      76.0     76.0            79.0           72.0     13.0
#          313      80.0     80.0            78.0           74.0     14.0
#          215      80.0     85.0            86.0           86.0      5.0
#          699      79.0     77.0            78.0           77.0      6.0
#
#              GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CDM      20         8.0      13.0           9.0        13.0    105600000.0
#          27        14.0      16.0          12.0        12.0    126400000.0
#          75        11.0       5.0          13.0         7.0     33300000.0
#          72         7.0      13.0           7.0         8.0     72600000.0
#          132       15.0      12.0          14.0         9.0     44400000.0
#          118       12.0       6.0           8.0         8.0     67200000.0
#          573        6.0       6.0          11.0        15.0     36000000.0
#          313       12.0       7.0          12.0         7.0     21300000.0
#          215       12.0       9.0          11.0         8.0     33000000.0
#          699       11.0      12.0          14.0         7.0     19000000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_rw['Overall'],bins=10,color='r')

# %%
fifa_topcdm=fifa_top100[fifa_top100['Position']=='CDM']
fifa_topcdm.Club.value_counts().head(10)
# Out:
# Sevilla FC           4
# SL Benfica           3
# Bologna              2
# Sassuolo             2
# Everton              2
# SV Werder Bremen     2
# Celtic               2
# VfL Wolfsburg        2
# FC Schalke 04        2
# Borussia Dortmund    2
# Name: Club, dtype: int64

# %% [markdown]
# ## CB

# %%
fifa_cb = fifa_sorted[fifa_sorted['Position']=='CB']
fifa_cb.head(10)
# Out:
#                   ID         Name  Age  Nationality  Overall  Potential  \
# Position
# CB       12   182493     D. Godín   32      Uruguay       90         90
#          42   205600    S. Umtiti   24       France       87         92
#          73   177509   M. Benatia   31      Morocco       86         86
#          89   192366  N. Otamendi   30    Argentina       85         85
#          102  171919        Naldo   35       Brazil       85         85
#          104  168609      Miranda   33       Brazil       85         85
#          107  139720   V. Kompany   32      Belgium       85         85
#          115  212190      N. Süle   22      Germany       84         90
#          127  198176   S. de Vrij   26  Netherlands       84         86
#          152  137186  A. Barzagli   37        Italy       84         84
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# CB       12     Atlético Madrid  125000  125000     1946  ...      82.0
#          42        FC Barcelona  205000  205000     2147  ...      82.0
#          73            Juventus  160000  160000     1803  ...      82.0
#          89     Manchester City  170000  170000     1916  ...      80.0
#          102      FC Schalke 04   38000   38000     1959  ...      84.0
#          104              Inter   96000   96000     1879  ...      81.0
#          107    Manchester City  170000  170000     1898  ...      81.0
#          115  FC Bayern München   84000   84000     1648  ...      72.0
#          127              Inter   88000   88000     1808  ...      82.0
#          152           Juventus   95000   95000     1740  ...      88.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# CB       12      90.0            89.0           89.0      6.0        8.0
#          42      90.0            89.0           86.0     15.0       10.0
#          73      89.0            87.0           85.0      7.0        4.0
#          89      83.0            85.0           84.0     12.0        5.0
#          102     86.0            88.0           85.0     14.0       10.0
#          104     90.0            90.0           85.0     12.0        6.0
#          107     87.0            85.0           84.0     10.0        9.0
#          115     82.0            85.0           83.0     15.0        7.0
#          127     88.0            87.0           83.0      8.0       10.0
#          152     94.0            90.0           82.0      4.0        2.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CB       12       15.0           5.0        15.0     90200000.0
#          42       14.0          12.0        15.0    121100000.0
#          73        8.0           7.0        11.0     49500000.0
#          89        8.0          11.0        12.0     52700000.0
#          102      14.0           8.0        14.0     15300000.0
#          104      10.0          13.0        12.0     26400000.0
#          107       5.0           8.0         6.0     40700000.0
#          115      14.0           7.0        15.0     67500000.0
#          127       7.0          14.0        13.0     55900000.0
#          152       4.0           2.0         4.0      6900000.0
#
# [10 rows x 85 columns]

# %%
fifa_cb.shape
# Out:
# (1778, 85)

# %%
fifa_cb.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                    ID             Name  Age Nationality  Overall  Potential  \
# Position
# CB       42    205600        S. Umtiti   24      France       87         92
#          188   200724  Nacho Fernández   28       Spain       83         85
#          107   139720       V. Kompany   32     Belgium       85         85
#          89    192366      N. Otamendi   30   Argentina       85         85
#          73    177509       M. Benatia   31     Morocco       86         86
#          12    182493         D. Godín   32     Uruguay       90         90
#          629   201862          M. Rojo   28   Argentina       79         79
#          311   165229     L. Koscielny   32      France       82         82
#          654   194957         P. Jones   26     England       79         80
#          1037  157304     T. Vermaelen   32     Belgium       77         77
#
#                             Club   Value    Wage  Special  ... Composure  \
# Position                                                   ...
# CB       42         FC Barcelona  205000  205000     2147  ...      82.0
#          188         Real Madrid  180000  180000     1855  ...      73.0
#          107     Manchester City  170000  170000     1898  ...      81.0
#          89      Manchester City  170000  170000     1916  ...      80.0
#          73             Juventus  160000  160000     1803  ...      82.0
#          12      Atlético Madrid  125000  125000     1946  ...      82.0
#          629   Manchester United  115000  115000     1998  ...      73.0
#          311             Arsenal  115000  115000     1807  ...      75.0
#          654   Manchester United  110000  110000     1827  ...      68.0
#          1037       FC Barcelona  110000  110000     1926  ...      72.0
#
#                Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# CB       42       90.0            89.0           86.0     15.0       10.0
#          188      75.0            86.0           85.0     12.0        7.0
#          107      87.0            85.0           84.0     10.0        9.0
#          89       83.0            85.0           84.0     12.0        5.0
#          73       89.0            87.0           85.0      7.0        4.0
#          12       90.0            89.0           89.0      6.0        8.0
#          629      76.0            81.0           79.0      7.0        8.0
#          311      80.0            84.0           83.0     13.0       11.0
#          654      76.0            81.0           82.0     10.0        8.0
#          1037     72.0            79.0           80.0      9.0       10.0
#
#               GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CB       42        14.0          12.0        15.0    121100000.0
#          188       10.0          15.0         7.0     52100000.0
#          107        5.0           8.0         6.0     40700000.0
#          89         8.0          11.0        12.0     52700000.0
#          73         8.0           7.0        11.0     49500000.0
#          12        15.0           5.0        15.0     90200000.0
#          629       12.0          15.0        10.0     18500000.0
#          311        9.0          11.0         7.0     23800000.0
#          654        6.0          16.0        11.0     23100000.0
#          1037       7.0          11.0        15.0     10300000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_cb['Overall'],bins=10,color='r')

# %%
fifa_topcb=fifa_top100[fifa_top100['Position']=='CB']
fifa_topcb.Club.value_counts().head(10)
# Out:
# Manchester United    4
# Juventus             3
# Manchester City      3
# Inter                3
# Everton              3
# Atlético Madrid      2
# Huddersfield Town    2
# Atalanta             2
# Hertha BSC           2
# Napoli               2
# Name: Club, dtype: int64

# %% [markdown]
# ## LB

# %%
fifa_lb = fifa_sorted[fifa_sorted['Position']=='LB']
fifa_lb.head(10)
# Out:
#                   ID           Name  Age Nationality  Overall  Potential  \
# Position
# LB       35   176676        Marcelo   30      Brazil       88         88
#          49   189332     Jordi Alba   29       Spain       87         87
#          64   191043    Alex Sandro   27      Brazil       86         86
#          85   197445       D. Alaba   26     Austria       85         87
#          106  164169    Filipe Luís   32      Brazil       85         85
#          112  212462    Alex Telles   25      Brazil       84         87
#          200  192638  Marcos Alonso   27       Spain       83         84
#          238  220814   L. Hernández   22      France       82         88
#          241  216267   A. Robertson   24    Scotland       82         87
#          291  185103     A. Kolarov   32      Serbia       82         82
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# LB       35         Real Madrid  285000  285000     2279  ...      86.0
#          49        FC Barcelona  250000  250000     2230  ...      79.0
#          64            Juventus  160000  160000     2198  ...      82.0
#          85   FC Bayern München  110000  110000     2261  ...      79.0
#          106    Atlético Madrid   81000   81000     2145  ...      88.0
#          112           FC Porto   22000   22000     2259  ...      80.0
#          200            Chelsea  130000  130000     2201  ...      76.0
#          238    Atlético Madrid   53000   53000     1953  ...      76.0
#          241          Liverpool   98000   98000     2023  ...      73.0
#          291               Roma   73000   73000     2230  ...      88.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# LB       35      71.0            85.0           86.0     12.0        5.0
#          49      72.0            84.0           85.0     13.0       15.0
#          64      81.0            84.0           84.0      7.0        7.0
#          85      80.0            82.0           80.0      5.0        7.0
#          106     78.0            84.0           86.0     11.0       15.0
#          112     80.0            81.0           79.0     13.0        8.0
#          200     79.0            82.0           79.0      9.0        7.0
#          238     76.0            83.0           86.0     10.0        7.0
#          241     80.0            81.0           78.0     11.0        8.0
#          291     81.0            82.0           81.0     16.0       15.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# LB       35        5.0           5.0         9.0     88200000.0
#          49       13.0           6.0        13.0     77900000.0
#          64        9.0          12.0         5.0     60200000.0
#          85       14.0          15.0         9.0     65600000.0
#          106       9.0           9.0         5.0     44100000.0
#          112      12.0          11.0        14.0     66400000.0
#          200      13.0           9.0        12.0     46200000.0
#          238       8.0          14.0        10.0     57400000.0
#          241      10.0           7.0        14.0     48400000.0
#          291       8.0          16.0         6.0     21300000.0
#
# [10 rows x 85 columns]

# %%
fifa_lb.shape
# Out:
# (1322, 85)

# %%
fifa_lb.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID           Name  Age Nationality  Overall  Potential  \
# Position
# LB       35   176676        Marcelo   30      Brazil       88         88
#          49   189332     Jordi Alba   29       Spain       87         87
#          64   191043    Alex Sandro   27      Brazil       86         86
#          200  192638  Marcos Alonso   27       Spain       83         84
#          514  183427       F. Delph   28     England       80         80
#          85   197445       D. Alaba   26     Austria       85         87
#          717  152908       A. Young   32     England       79         79
#          352  204884       B. Mendy   23      France       81         86
#          520  177604  Nacho Monreal   32       Spain       80         80
#          241  216267   A. Robertson   24    Scotland       82         87
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# LB       35         Real Madrid  285000  285000     2279  ...      86.0
#          49        FC Barcelona  250000  250000     2230  ...      79.0
#          64            Juventus  160000  160000     2198  ...      82.0
#          200            Chelsea  130000  130000     2201  ...      76.0
#          514    Manchester City  120000  120000     2137  ...      76.0
#          85   FC Bayern München  110000  110000     2261  ...      79.0
#          717  Manchester United  110000  110000     2120  ...      74.0
#          352    Manchester City  105000  105000     2038  ...      79.0
#          520            Arsenal   99000   99000     2011  ...      76.0
#          241          Liverpool   98000   98000     2023  ...      73.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# LB       35      71.0            85.0           86.0     12.0        5.0
#          49      72.0            84.0           85.0     13.0       15.0
#          64      81.0            84.0           84.0      7.0        7.0
#          200     79.0            82.0           79.0      9.0        7.0
#          514     77.0            81.0           79.0     10.0        9.0
#          85      80.0            82.0           80.0      5.0        7.0
#          717     75.0            76.0           74.0     16.0       10.0
#          352     78.0            79.0           81.0      7.0        7.0
#          520     80.0            83.0           81.0      7.0        5.0
#          241     80.0            81.0           78.0     11.0        8.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# LB       35        5.0           5.0         9.0     88200000.0
#          49       13.0           6.0        13.0     77900000.0
#          64        9.0          12.0         5.0     60200000.0
#          200      13.0           9.0        12.0     46200000.0
#          514      14.0          11.0         6.0     21300000.0
#          85       14.0          15.0         9.0     65600000.0
#          717      15.0          16.0        15.0     13000000.0
#          352       9.0          15.0         9.0     38500000.0
#          520       9.0           3.0         5.0     15200000.0
#          241      10.0           7.0        14.0     48400000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_lb['Overall'],bins=10,color='r')

# %%
fifa_toplb=fifa_top100[fifa_top100['Position']=='LB']
fifa_toplb.Club.value_counts().head(10)
# Out:
# Inter                  3
# Manchester United      3
# West Ham United        2
# Everton                2
# RC Celta               2
# Beşiktaş JK            2
# Paris Saint-Germain    2
# Sporting CP            2
# Bournemouth            2
# Bayer 04 Leverkusen    2
# Name: Club, dtype: int64

# %% [markdown]
# ## GK

# %%
fifa_gk = fifa_sorted[fifa_sorted['Position']=='GK']
fifa_gk.head(10)
# Out:
#                  ID           Name  Age Nationality  Overall  Potential  \
# Position
# GK       3   193080         De Gea   27       Spain       91         93
#          9   200389       J. Oblak   25    Slovenia       90         93
#          18  192448  M. ter Stegen   26     Germany       89         92
#          19  192119    T. Courtois   26     Belgium       89         90
#          22  167495       M. Neuer   32     Germany       89         89
#          37  167948      H. Lloris   31      France       88         88
#          40  162835  S. Handanovič   33    Slovenia       88         88
#          41    1179      G. Buffon   40       Italy       88         88
#          46  193041       K. Navas   31  Costa Rica       87         87
#          57  210257        Ederson   24      Brazil       86         90
#
#                             Club   Value    Wage  Special  ... Composure  \
# Position                                                   ...
# GK       3     Manchester United  260000  260000     1471  ...      68.0
#          9       Atlético Madrid   94000   94000     1331  ...      70.0
#          18         FC Barcelona  240000  240000     1328  ...      69.0
#          19          Real Madrid  240000  240000     1311  ...      66.0
#          22    FC Bayern München  130000  130000     1473  ...      70.0
#          37    Tottenham Hotspur  150000  150000     1335  ...      65.0
#          40                Inter  110000  110000     1262  ...      69.0
#          41  Paris Saint-Germain   77000   77000     1334  ...      70.0
#          46          Real Madrid  195000  195000     1345  ...      67.0
#          57      Manchester City  125000  125000     1463  ...      70.0
#
#              Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# GK       3      15.0            21.0           13.0     90.0       85.0
#          9      27.0            12.0           18.0     86.0       92.0
#          18     25.0            13.0           10.0     87.0       85.0
#          19     20.0            18.0           16.0     85.0       91.0
#          22     17.0            10.0           11.0     90.0       86.0
#          37     29.0            10.0           18.0     88.0       84.0
#          40     25.0            10.0           13.0     87.0       86.0
#          41     13.0            11.0           11.0     88.0       87.0
#          46     28.0            14.0           14.0     90.0       81.0
#          57     28.0            15.0            8.0     85.0       80.0
#
#             GKKicking GKPositioning  GKReflexes Release Clause
# Position
# GK       3       87.0          88.0        94.0    138600000.0
#          9       78.0          88.0        89.0    144500000.0
#          18      88.0          85.0        90.0    123300000.0
#          19      72.0          86.0        88.0    113700000.0
#          22      91.0          87.0        87.0     62700000.0
#          37      68.0          83.0        92.0     66600000.0
#          40      69.0          89.0        89.0     51000000.0
#          41      74.0          90.0        83.0      7400000.0
#          46      75.0          82.0        90.0     62500000.0
#          57      91.0          82.0        87.0     79900000.0
#
# [10 rows x 85 columns]

# %%
fifa_gk.shape
# Out:
# (2025, 85)

# %%
fifa_gk.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID           Name  Age  Nationality  Overall  Potential  \
# Position
# GK       3    193080         De Gea   27        Spain       91         93
#          18   192448  M. ter Stegen   26      Germany       89         92
#          19   192119    T. Courtois   26      Belgium       89         90
#          46   193041       K. Navas   31   Costa Rica       87         87
#          37   167948      H. Lloris   31       France       88         88
#          266  199987   J. Cillessen   29  Netherlands       82         84
#          22   167495       M. Neuer   32      Germany       89         89
#          57   210257        Ederson   24       Brazil       86         90
#          92   186153    W. Szczęsny   28       Poland       85         87
#          131  192563        B. Leno   26      Germany       84         87
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# GK       3    Manchester United  260000  260000     1471  ...      68.0
#          18        FC Barcelona  240000  240000     1328  ...      69.0
#          19         Real Madrid  240000  240000     1311  ...      66.0
#          46         Real Madrid  195000  195000     1345  ...      67.0
#          37   Tottenham Hotspur  150000  150000     1335  ...      65.0
#          266       FC Barcelona  135000  135000     1292  ...      61.0
#          22   FC Bayern München  130000  130000     1473  ...      70.0
#          57     Manchester City  125000  125000     1463  ...      70.0
#          92            Juventus  125000  125000     1270  ...      65.0
#          131            Arsenal  115000  115000     1278  ...      66.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# GK       3       15.0            21.0           13.0     90.0       85.0
#          18      25.0            13.0           10.0     87.0       85.0
#          19      20.0            18.0           16.0     85.0       91.0
#          46      28.0            14.0           14.0     90.0       81.0
#          37      29.0            10.0           18.0     88.0       84.0
#          266     18.0            12.0           11.0     80.0       83.0
#          22      17.0            10.0           11.0     90.0       86.0
#          57      28.0            15.0            8.0     85.0       80.0
#          92      20.0            13.0           12.0     85.0       81.0
#          131     27.0            15.0           18.0     84.0       82.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# GK       3        87.0          88.0        94.0    138600000.0
#          18       88.0          85.0        90.0    123300000.0
#          19       72.0          86.0        88.0    113700000.0
#          46       75.0          82.0        90.0     62500000.0
#          37       68.0          83.0        92.0     66600000.0
#          266      75.0          81.0        80.0     38300000.0
#          22       91.0          87.0        87.0     62700000.0
#          57       91.0          82.0        87.0     79900000.0
#          92       71.0          85.0        87.0     55200000.0
#          131      75.0          85.0        82.0     53300000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_gk['Overall'],bins=10,color='r')

# %%
fifa_topGK=fifa_top100[fifa_top100['Position']=='GK']
fifa_topGK.Club.value_counts().head(10)
# Out:
# Real Madrid          3
# Burnley              3
# Manchester United    2
# Real Sociedad        2
# Milan                2
# Napoli               2
# Borussia Dortmund    2
# Arsenal              2
# Atlético Madrid      2
# Fulham               2
# Name: Club, dtype: int64

# %% [markdown]
# ## RB

# %%
fifa_rb = fifa_sorted[fifa_sorted['Position']=='RB']
fifa_rb.head(10)
# Out:
#                   ID             Name  Age Nationality  Overall  Potential  \
# Position
# RB       69   184432      Azpilicueta   28       Spain       86         86
#          135  188377        K. Walker   28     England       84         84
#          123  204963         Carvajal   26       Spain       84         87
#          192  199564    Sergi Roberto   26       Spain       83         86
#          216  177457        L. Bender   29     Germany       83         83
#          247  210514     João Cancelo   24    Portugal       82         88
#          258  203551      A. Florenzi   27       Italy       82         83
#          276  193525  Mário Fernandes   27      Russia       82         82
#          290  186345      K. Trippier   27     England       82         82
#          314  146530       Dani Alves   35      Brazil       82         82
#
#                              Club   Value    Wage  Special  ... Composure  \
# Position                                                    ...
# RB       69               Chelsea  175000  175000     2114  ...      78.0
#          135      Manchester City  165000  165000     2175  ...      75.0
#          123          Real Madrid  185000  185000     2040  ...      77.0
#          192         FC Barcelona  170000  170000     2106  ...      76.0
#          216  Bayer 04 Leverkusen   82000   82000     2049  ...      83.0
#          247             Juventus   95000   95000     2174  ...      77.0
#          258                 Roma   73000   73000     2253  ...      79.0
#          276      PFC CSKA Moscow    1000    1000     2102  ...      76.0
#          290    Tottenham Hotspur   99000   99000     2161  ...      73.0
#          314  Paris Saint-Germain   62000   62000     2197  ...      80.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# RB       69      88.0            90.0           86.0     13.0        9.0
#          135     78.0            84.0           83.0     12.0        6.0
#          123     83.0            83.0           85.0     13.0       13.0
#          192     75.0            83.0           83.0     14.0       16.0
#          216     88.0            86.0           82.0     12.0        6.0
#          247     79.0            79.0           79.0      6.0        9.0
#          258     76.0            79.0           78.0      9.0        8.0
#          276     83.0            82.0           84.0     12.0       13.0
#          290     77.0            82.0           79.0     11.0       14.0
#          314     72.0            79.0           82.0      5.0       11.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# RB       69       10.0           6.0         5.0     64800000.0
#          135      16.0          15.0         8.0     45300000.0
#          123      15.0           9.0        15.0     66900000.0
#          192      11.0          15.0        10.0     56300000.0
#          216       7.0          12.0         7.0     34000000.0
#          247      15.0          14.0        14.0     47200000.0
#          258      10.0          11.0        10.0     36400000.0
#          276      14.0          13.0        12.0     40700000.0
#          290       8.0          11.0        10.0     34200000.0
#          314       9.0           6.0         7.0      8900000.0
#
# [10 rows x 85 columns]

# %%
fifa_rb.shape
# Out:
# (1291, 85)

# %%
fifa_rb.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID           Name  Age Nationality  Overall  Potential  \
# Position
# RB       123  204963       Carvajal   26       Spain       84         87
#          69   184432    Azpilicueta   28       Spain       86         86
#          192  199564  Sergi Roberto   26       Spain       83         86
#          135  188377      K. Walker   28     England       84         84
#          324  227928  Nélson Semedo   24    Portugal       81         86
#          417  234035      Odriozola   22       Spain       80         88
#          645  199304         Danilo   26      Brazil       79         80
#          290  186345    K. Trippier   27     England       82         82
#          247  210514   João Cancelo   24    Portugal       82         88
#          590  216150  D. Zappacosta   26       Italy       79         81
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# RB       123        Real Madrid  185000  185000     2040  ...      77.0
#          69             Chelsea  175000  175000     2114  ...      78.0
#          192       FC Barcelona  170000  170000     2106  ...      76.0
#          135    Manchester City  165000  165000     2175  ...      75.0
#          324       FC Barcelona  125000  125000     2039  ...      75.0
#          417        Real Madrid  115000  115000     1991  ...      69.0
#          645    Manchester City  110000  110000     2128  ...      69.0
#          290  Tottenham Hotspur   99000   99000     2161  ...      73.0
#          247           Juventus   95000   95000     2174  ...      77.0
#          590            Chelsea   94000   94000     2069  ...      73.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# RB       123     83.0            83.0           85.0     13.0       13.0
#          69      88.0            90.0           86.0     13.0        9.0
#          192     75.0            83.0           83.0     14.0       16.0
#          135     78.0            84.0           83.0     12.0        6.0
#          324     75.0            78.0           79.0     16.0       12.0
#          417     83.0            79.0           80.0     11.0       12.0
#          645     78.0            77.0           78.0     14.0        5.0
#          290     77.0            82.0           79.0     11.0       14.0
#          247     79.0            79.0           79.0      6.0        9.0
#          590     76.0            78.0           79.0     11.0        9.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# RB       123      15.0           9.0        15.0     66900000.0
#          69       10.0           6.0         5.0     64800000.0
#          192      11.0          15.0        10.0     56300000.0
#          135      16.0          15.0         8.0     45300000.0
#          324      10.0          14.0        12.0     42500000.0
#          417      10.0           5.0        14.0     41600000.0
#          645      15.0          14.0         5.0     23100000.0
#          290       8.0          11.0        10.0     34200000.0
#          247      15.0          14.0        14.0     47200000.0
#          590       8.0           6.0        11.0     24100000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_rb['Overall'],bins=10,color='r')

# %%
fifa_toprb=fifa_top100[fifa_top100['Position']=='RB']
fifa_toprb.Club.value_counts().head(10)
# Out:
# Olympique Lyonnais         3
# Athletic Club de Bilbao    3
# Chelsea                    2
# Leicester City             2
# Olympique de Marseille     2
# Watford                    2
# Liverpool                  2
# Manchester City            2
# Arsenal                    2
# Bournemouth                2
# Name: Club, dtype: int64

# %% [markdown]
# ## CM

# %%
fifa_cm = fifa_sorted[fifa_sorted['Position']=='CM']
fifa_cm.head(10)
# Out:
#                   ID                 Name  Age Nationality  Overall  \
# Position
# CM       67   189509               Thiago   27       Spain       86
#          78   223848  S. Milinković-Savić   23      Serbia       85
#          121  205498             Jorginho   26       Italy       84
#          136  186942          I. Gündoğan   27     Germany       84
#          161  220971             N. Keïta   23      Guinea       83
#          162  219683           C. Tolisso   23      France       83
#          168  210008            A. Rabiot   23      France       83
#          169  209658          L. Goretzka   23     Germany       83
#          184  202166           J. Draxler   24     Germany       83
#          219  162895        Cesc Fàbregas   31       Spain       83
#
#               Potential                 Club   Value    Wage  Special  ...  \
# Position                                                               ...
# CM       67          86    FC Bayern München  130000  130000     2190  ...
#          78          90                Lazio   73000   73000     2206  ...
#          121         87              Chelsea  155000  155000     2136  ...
#          136         84      Manchester City  175000  175000     2138  ...
#          161         88            Liverpool  120000  120000     2082  ...
#          162         88    FC Bayern München   85000   85000     2207  ...
#          168         87  Paris Saint-Germain   91000   91000     2184  ...
#          169         88    FC Bayern München   85000   85000     2203  ...
#          184         86  Paris Saint-Germain   91000   91000     2112  ...
#          219         83              Chelsea  140000  140000     2040  ...
#
#              Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# Position
# CM       67       85.0     67.0            63.0           65.0      6.0
#          78       82.0     75.0            77.0           72.0      7.0
#          121      79.0     63.0            78.0           70.0     14.0
#          136      87.0     73.0            68.0           64.0     11.0
#          161      79.0     68.0            62.0           61.0      7.0
#          162      74.0     75.0            78.0           71.0      7.0
#          168      82.0     70.0            81.0           75.0      9.0
#          169      80.0     70.0            79.0           78.0     13.0
#          184      83.0     39.0            64.0           44.0     11.0
#          219      92.0     64.0            59.0           58.0      6.0
#
#              GKHandling GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CM       67        11.0       7.0           9.0        13.0     75100000.0
#          78        10.0       7.0          16.0         7.0     89600000.0
#          121        7.0      13.0          14.0         8.0     73200000.0
#          136       14.0       5.0           5.0        13.0     59200000.0
#          161       14.0      15.0          14.0         9.0     67200000.0
#          162       10.0      14.0           9.0        14.0     58700000.0
#          168       12.0       9.0           7.0        15.0     63500000.0
#          169        8.0      15.0          11.0         9.0     58700000.0
#          184       13.0       5.0          13.0         8.0     62600000.0
#          219       10.0       8.0          15.0        15.0     40700000.0
#
# [10 rows x 85 columns]

# %%
fifa_cm.shape
# Out:
# (1394, 85)

# %%
fifa_cm.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID           Name  Age Nationality  Overall  Potential  \
# Position
# CM       136  186942    I. Gündoğan   27     Germany       84         84
#          121  205498       Jorginho   26       Italy       84         87
#          250  209297           Fred   25      Brazil       82         84
#          374  191740  Ander Herrera   28       Spain       81         81
#          219  162895  Cesc Fàbregas   31       Spain       83         83
#          67   189509         Thiago   27       Spain       86         86
#          161  220971       N. Keïta   23      Guinea       83         88
#          700  176944    M. Fellaini   30     Belgium       79         79
#          409  138412      J. Milner   32     England       81         81
#          613  205192   Denis Suárez   24       Spain       79         86
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# CM       136    Manchester City  175000  175000     2138  ...      87.0
#          121            Chelsea  155000  155000     2136  ...      79.0
#          250  Manchester United  140000  140000     2180  ...      82.0
#          374  Manchester United  140000  140000     2170  ...      84.0
#          219            Chelsea  140000  140000     2040  ...      92.0
#          67   FC Bayern München  130000  130000     2190  ...      85.0
#          161          Liverpool  120000  120000     2082  ...      79.0
#          700  Manchester United  120000  120000     1994  ...      78.0
#          409          Liverpool  120000  120000     2126  ...      86.0
#          613       FC Barcelona  120000  120000     2016  ...      70.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# CM       136     73.0            68.0           64.0     11.0       14.0
#          121     63.0            78.0           70.0     14.0        7.0
#          250     76.0            78.0           69.0      7.0       16.0
#          374     78.0            80.0           77.0      9.0       12.0
#          219     64.0            59.0           58.0      6.0       10.0
#          67      67.0            63.0           65.0      6.0       11.0
#          161     68.0            62.0           61.0      7.0       14.0
#          700     77.0            77.0           60.0      8.0        6.0
#          409     74.0            80.0           79.0      1.0        1.0
#          613     69.0            59.0           42.0     10.0       14.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# CM       136       5.0           5.0        13.0     59200000.0
#          121      13.0          14.0         8.0     73200000.0
#          250      15.0          11.0        15.0     51000000.0
#          374      15.0           9.0         8.0     32400000.0
#          219       8.0          15.0        15.0     40700000.0
#          67        7.0           9.0        13.0     75100000.0
#          161      15.0          14.0         9.0     67200000.0
#          700       9.0          15.0        16.0     21300000.0
#          409       1.0           1.0         1.0     25700000.0
#          613      10.0           7.0         7.0     39400000.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_cm['Overall'],bins=10,color='r')

# %%
fifa_topcm=fifa_top100[fifa_top100['Position']=='CM']
fifa_topcm.Club.value_counts().head(10)
# Out:
# Chelsea                    5
# Manchester United          4
# Liverpool                  4
# Tottenham Hotspur          3
# FC Porto                   3
# Milan                      3
# FC Bayern München          3
# Paris Saint-Germain        3
# Athletic Club de Bilbao    3
# Dynamo Kyiv                2
# Name: Club, dtype: int64

# %% [markdown]
# ## LCM

# %%
fifa_lcm = fifa_sorted[fifa_sorted['Position']=='LCM']
fifa_lcm.head(10)
# Out:
#                   ID             Name  Age Nationality  Overall  Potential  \
# Position
# LCM      11   182521         T. Kroos   28     Germany       90         90
#          13   168542      David Silva   32       Spain       90         90
#          52   171877        M. Hamšík   30    Slovakia       87         87
#          63   199556      M. Verratti   25       Italy       86         89
#          114  212198  Bruno Fernandes   23    Portugal       84         88
#          117  211117          D. Alli   22     England       84         90
#          143  177413        A. Witsel   29     Belgium       84         84
#          195  195365         K. Kampl   27    Slovenia       83         83
#          205  188152            Oscar   26      Brazil       83         84
#          194  197965            Pizzi   28    Portugal       83         83
#
#                              Club   Value    Wage  Special  ... Composure  \
# Position                                                    ...
# LCM      11           Real Madrid  355000  355000     2190  ...      85.0
#          13       Manchester City  285000  285000     2115  ...      93.0
#          52                Napoli  125000  125000     2188  ...      84.0
#          63   Paris Saint-Germain  135000  135000     2149  ...      93.0
#          114          Sporting CP   22000   22000     2223  ...      83.0
#          117    Tottenham Hotspur  115000  115000     2189  ...      86.0
#          143    Borussia Dortmund   77000   77000     2200  ...      89.0
#          195           RB Leipzig   74000   74000     2076  ...      83.0
#          205     Shanghai SIPG FC   29000   29000     2022  ...      75.0
#          194           SL Benfica   22000   22000     2149  ...      85.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# LCM      11      72.0            79.0           69.0     10.0       11.0
#          13      59.0            53.0           29.0      6.0       15.0
#          52      75.0            73.0           62.0      8.0        6.0
#          63      78.0            83.0           80.0     12.0       12.0
#          114     63.0            66.0           53.0     12.0       14.0
#          117     70.0            70.0           63.0      7.0        6.0
#          143     80.0            79.0           85.0      5.0        7.0
#          195     65.0            64.0           59.0     13.0       11.0
#          205     66.0            52.0           47.0     12.0       10.0
#          194     66.0            66.0           52.0     15.0       14.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# LCM      11       13.0           7.0        10.0    156800000.0
#          13        7.0           6.0        12.0    111000000.0
#          52        4.0          14.0        14.0     79100000.0
#          63       15.0          15.0        10.0    105900000.0
#          114      15.0           8.0        14.0     84000000.0
#          117       9.0          11.0         8.0     87100000.0
#          143       7.0          10.0         7.0     40800000.0
#          195       7.0           6.0        16.0     45100000.0
#          205      15.0          12.0        12.0     69400000.0
#          194       9.0           9.0        15.0     51000000.0
#
# [10 rows x 85 columns]

# %%
fifa_lcm.shape
# Out:
# (395, 85)

# %%
fifa_lcm.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID           Name  Age Nationality  Overall  Potential  \
# Position
# LCM      11   182521       T. Kroos   28     Germany       90         90
#          13   168542    David Silva   32       Spain       90         90
#          176  207410     M. Kovačić   24     Croatia       83         89
#          63   199556    M. Verratti   25       Italy       86         89
#          228  230658         Arthur   21      Brazil       82         90
#          52   171877      M. Hamšík   30    Slovakia       87         87
#          328  222509  Dani Ceballos   21       Spain       81         88
#          117  211117        D. Alli   22     England       84         90
#          235  223959    L. Torreira   22     Uruguay       82         87
#          434  219809    T. Bakayoko   23      France       80         85
#
#                              Club   Value    Wage  Special  ... Composure  \
# Position                                                    ...
# LCM      11           Real Madrid  355000  355000     2190  ...      85.0
#          13       Manchester City  285000  285000     2115  ...      93.0
#          176              Chelsea  165000  165000     2115  ...      72.0
#          63   Paris Saint-Germain  135000  135000     2149  ...      93.0
#          228         FC Barcelona  125000  125000     2120  ...      84.0
#          52                Napoli  125000  125000     2188  ...      84.0
#          328          Real Madrid  120000  120000     2059  ...      80.0
#          117    Tottenham Hotspur  115000  115000     2189  ...      86.0
#          235              Arsenal   98000   98000     2111  ...      78.0
#          434                Milan   85000   85000     1928  ...      68.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# LCM      11      72.0            79.0           69.0     10.0       11.0
#          13      59.0            53.0           29.0      6.0       15.0
#          176     69.0            75.0           63.0      9.0        5.0
#          63      78.0            83.0           80.0     12.0       12.0
#          228     65.0            76.0           70.0      6.0       13.0
#          52      75.0            73.0           62.0      8.0        6.0
#          328     62.0            75.0           74.0     12.0       15.0
#          117     70.0            70.0           63.0      7.0        6.0
#          235     84.0            84.0           75.0      5.0        5.0
#          434     71.0            84.0           82.0     11.0       15.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# LCM      11       13.0           7.0        10.0    156800000.0
#          13        7.0           6.0        12.0    111000000.0
#          176       6.0           7.0         7.0            0.0
#          63       15.0          15.0        10.0    105900000.0
#          228      13.0          11.0        12.0     73100000.0
#          52        4.0          14.0        14.0     79100000.0
#          328      16.0           7.0        13.0     56300000.0
#          117       9.0          11.0         8.0     87100000.0
#          235      13.0           7.0         9.0     49400000.0
#          434      11.0          14.0        10.0            0.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_lcm['Overall'],bins=10,color='r')

# %%
fifa_toplcm=fifa_top100[fifa_top100['Position']=='LCM']
fifa_toplcm.Club.value_counts().head(10)
# Out:
# Real Madrid          2
# Borussia Dortmund    2
# PSV                  2
# FC Schalke 04        2
# Aston Villa          2
# Tottenham Hotspur    1
# Derby County         1
# Angers SCO           1
# Portimonense SC      1
# UD Las Palmas        1
# Name: Club, dtype: int64

# %% [markdown]
# ## RCM

# %%
fifa_rcm = fifa_sorted[fifa_sorted['Position']=='RCM']
fifa_rcm.head(10)
# Out:
#                   ID              Name  Age Nationality  Overall  Potential  \
# Position
# RCM      4    192985      K. De Bruyne   27     Belgium       91         92
#          6    177003         L. Modrić   32     Croatia       91         91
#          53   168651        I. Rakitić   30     Croatia       87         87
#          82   212622        J. Kimmich   23     Germany       85         88
#          83   208421              Saúl   23       Spain       85         90
#          90   189513            Parejo   29       Spain       85         85
#          99   179846        S. Khedira   31     Germany       85         85
#          178  206545    Manu Trigueros   26       Spain       83         84
#          190  199914             Allan   27      Brazil       83         83
#          230  230258  Rosberto Dourado   30      Brazil       82         82
#
#                            Club   Value    Wage  Special  ... Composure  \
# Position                                                  ...
# RCM      4      Manchester City  355000  355000     2281  ...      88.0
#          6          Real Madrid  420000  420000     2280  ...      84.0
#          53        FC Barcelona  260000  260000     2184  ...      81.0
#          82   FC Bayern München   92000   92000     2185  ...      82.0
#          83     Atlético Madrid   77000   77000     2196  ...      83.0
#          90         Valencia CF   66000   66000     2119  ...      78.0
#          99            Juventus  160000  160000     2154  ...      84.0
#          178      Villarreal CF   49000   49000     2121  ...      73.0
#          190             Napoli   87000   87000     2157  ...      79.0
#          230   Atlético Mineiro   46000   46000     2061  ...      81.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# RCM      4       68.0            58.0           51.0     15.0       13.0
#          6       60.0            76.0           73.0     13.0        9.0
#          53      72.0            74.0           70.0     14.0       11.0
#          82      75.0            81.0           79.0      8.0       15.0
#          83      77.0            79.0           76.0      7.0       13.0
#          90      69.0            68.0           60.0      5.0        9.0
#          99      80.0            83.0           76.0     11.0        9.0
#          178     70.0            73.0           60.0      9.0       14.0
#          190     85.0            85.0           83.0     13.0       13.0
#          230     83.0            86.0           80.0     15.0       14.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# RCM      4         5.0          10.0        13.0    196400000.0
#          6         7.0          14.0         9.0    137400000.0
#          53       12.0           5.0         9.0     95300000.0
#          82        7.0          15.0        15.0     69900000.0
#          83       12.0          10.0         9.0    107300000.0
#          90       12.0          14.0         8.0     77700000.0
#          99        5.0          15.0         8.0     54500000.0
#          178      12.0           7.0         8.0     65300000.0
#          190       5.0           5.0         8.0     45100000.0
#          230      14.0          10.0         9.0     31400000.0
#
# [10 rows x 85 columns]

# %%
fifa_rcm.shape
# Out:
# (391, 85)

# %%
fifa_rcm.sort_values(by='Wage',ascending=False).head(10)
# Out:
#                   ID           Name  Age Nationality  Overall  Potential  \
# Position
# RCM      6    177003      L. Modrić   32     Croatia       91         91
#          4    192985   K. De Bruyne   27     Belgium       91         92
#          53   168651     I. Rakitić   30     Croatia       87         87
#          99   179846     S. Khedira   31     Germany       85         85
#          296  183711   J. Henderson   28     England       82         82
#          82   212622     J. Kimmich   23     Germany       85         88
#          190  199914          Allan   27      Brazil       83         83
#          401  162347  João Moutinho   31    Portugal       81         81
#          83   208421           Saúl   23       Spain       85         90
#          427  226226    G. Lo Celso   22   Argentina       80         86
#
#                                  Club   Value    Wage  Special  ... Composure  \
# Position                                                        ...
# RCM      6                Real Madrid  420000  420000     2280  ...      84.0
#          4            Manchester City  355000  355000     2281  ...      88.0
#          53              FC Barcelona  260000  260000     2184  ...      81.0
#          99                  Juventus  160000  160000     2154  ...      84.0
#          296                Liverpool  125000  125000     2163  ...      78.0
#          82         FC Bayern München   92000   92000     2185  ...      82.0
#          190                   Napoli   87000   87000     2157  ...      79.0
#          401  Wolverhampton Wanderers   85000   85000     2164  ...      86.0
#          83           Atlético Madrid   77000   77000     2196  ...      83.0
#          427               Real Betis   72000   72000     2105  ...      79.0
#
#               Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# Position
# RCM      6       60.0            76.0           73.0     13.0        9.0
#          4       68.0            58.0           51.0     15.0       13.0
#          53      72.0            74.0           70.0     14.0       11.0
#          99      80.0            83.0           76.0     11.0        9.0
#          296     77.0            79.0           76.0      7.0       13.0
#          82      75.0            81.0           79.0      8.0       15.0
#          190     85.0            85.0           83.0     13.0       13.0
#          401     68.0            72.0           68.0     13.0       15.0
#          83      77.0            79.0           76.0      7.0       13.0
#          427     61.0            67.0           67.0     10.0        7.0
#
#              GKKicking GKPositioning  GKReflexes Release Clause
# Position
# RCM      6         7.0          14.0         9.0    137400000.0
#          4         5.0          10.0        13.0    196400000.0
#          53       12.0           5.0         9.0     95300000.0
#          99        5.0          15.0         8.0     54500000.0
#          296       7.0           9.0        13.0     34200000.0
#          82        7.0          15.0        15.0     69900000.0
#          190       5.0           5.0         8.0     45100000.0
#          401      15.0          13.0        13.0     28500000.0
#          83       12.0          10.0         9.0    107300000.0
#          427      10.0          15.0        14.0            0.0
#
# [10 rows x 85 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(112, 8)
sns.displot(fifa_rcm['Overall'],bins=10,color='r')

# %%
fifa_toprcm=fifa_top100[fifa_top100['Position']=='RCM']
fifa_toprcm.Club.value_counts().head(10)
# Out:
# Southampton      3
# PSV              2
# Villarreal CF    2
# Cardiff City     2
# Real Betis       2
# Napoli           2
# KRC Genk         2
# Juventus         2
# SD Huesca        1
# SC Braga         1
# Name: Club, dtype: int64
